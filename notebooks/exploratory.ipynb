# %%
import pandas as pd
df = pd.read_csv("../data/processed/merged_panel.csv")
df.head()
# Out:
#             State  Year  Kharif_Rain_mm  Yield_t_ha
# 0  Andhra Pradesh  2000          832.93    2.983832
# 1  Andhra Pradesh  2001          509.79    3.110354
# 2  Andhra Pradesh  2002          380.95    2.846813
# 3  Andhra Pradesh  2003          501.31    3.093061
# 4  Andhra Pradesh  2004          490.10    3.318536

# %%
df.info()
df.describe()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           380 non-null    object
#  1   Year            380 non-null    int64
#  2   Kharif_Rain_mm  380 non-null    float64
#  3   Yield_t_ha      380 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 12.0+ KB
# State             0
# Year              0
# Kharif_Rain_mm    0
# Yield_t_ha        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.scatter(df['Kharif_Rain_mm'], df['Yield_t_ha'], alpha=0.6)
plt.xlabel("Kharif Rainfall (mm)")
plt.ylabel("Yield (t/ha)")
plt.title("Rainfall vs Rice Yield (India 2000-2019)")
plt.show()

# %%
df[['Kharif_Rain_mm', 'Yield_t_ha']].corr()
# Out:
#                 Kharif_Rain_mm  Yield_t_ha
# Kharif_Rain_mm         1.00000    -0.31843
# Yield_t_ha            -0.31843     1.00000
